# %%
import pandas as pd

# %%
# Load the autoreload extension
# %load_ext autoreload

# Set autoreload to automatically reload all modules before execution
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
print(os.getcwd())
os.chdir('c:/Users/hp/Desktop/tutorial/kaim-week-3')
# Out:
# c:\Users\hp\Desktop\tutorial\kaim-week-3

# %%
data = pd.read_csv('c:/Users/hp/Desktop/tutorial/kaim-week-3/datas/raw/MachineLearningRating_v3_new.csv')

# %% [markdown]
# The first one we will be seeing is risk across province

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached scipy-1.14.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
# Using cached scipy-1.14.1-cp313-cp313-win_amd64.whl (44.5 MB)
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scripts.AB_hypothesis import risk_across_province
province_risk=risk_across_province(data)
province_risk
# Out:
# {'test': 'ANOVA',
#  'Null Hypothesis': 'No risk difference across provinces',
#  'p-value': np.float64(1.6782057588675903e-07),
#  'f-statistics': np.float64(5.849413762407606),
#  'reject null': np.True_}

# %% [markdown]
# The risk between Postalcodes

# %%
from scripts.AB_hypothesis import risk_between_postalcodes
postal_risk=risk_between_postalcodes(data)
postal_risk
# Out:
# {'test': 'ANOVA',
#  'Null Hypothesis': 'No risk difference across PostalCodes',
#  'p-value': np.float64(0.8906511279164051),
#  'f-statistics': np.float64(0.9419762214391849),
#  'reject null': np.False_}

# %% [markdown]
# the test margin difference between postalcodes

# %%
from scripts.AB_hypothesis import marigin_between_postalcode
postal_marigin=marigin_between_postalcode(data)
postal_marigin
# Out:
# {'test': 'ANOVA',
#  'Null Hypothesis': 'No profit difference across PostalCodes',
#  'p-value': np.float64(0.9976859758015036),
#  'f-statistics': np.float64(0.8707474893589263),
#  'reject null': np.False_}

# %%
from scripts.AB_hypothesis import risk_across_gender
gender_risk=risk_across_gender(data)
gender_risk
# Out:
# {'test': 'ANOVA',
#  'Null Hypothesis': 'No profit difference across PostalCodes',
#  'p-value': np.float64(0.9627345778712776),
#  'f-statistics': np.float64(-0.04672340748722213),
#  'reject null': np.False_}
