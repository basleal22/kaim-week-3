# %%
import pandas as pd
import os

# %%
os.chdir('C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3')

# %%
# !pip install joblib
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# load our xgb and rf model

# %%
import joblib

# %%
import xgboost as xgb

# %%
loaded_model_xgb = joblib.load("C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3/models/xgb_model_2.jotlib")
loaded_model_rf = joblib.load("C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3/models/rf_model.jotlib")

# %%
x_train_rf=pd.read_csv('C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3/data/preprocessed/data_rf/X_train.csv')
x_test_rf=pd.read_csv('C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3/data/preprocessed/data_rf/X_test.csv')
y_train_rf=pd.read_csv('C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3/data/preprocessed/data_rf/y_train.csv')
y_test_rf=pd.read_csv('C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3/data/preprocessed/data_rf/y_test.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x_train_rf=pd.read_csv('C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3/data/preprocessed/data_rf/X_train.csv')
#       2 x_test_rf=pd.read_csv('C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3/data/preprocessed/data_rf/X_test.csv')
#       3 y_train_rf=pd.read_csv('C:/Users/basleal/Desktop/tutorial/kaim-week-3/kaim-week-3/data/preprocessed/data_rf/y_train.csv')
#
# NameError: name 'pd' is not defined
